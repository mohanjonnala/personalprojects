# %%
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#%matplotlib inline
import tensorflow as tf
import keras.backend as K
# import keras
# from ensorflow import keras
from keras import layers
from keras.models import Model, load_model
from keras.layers import Input, BatchNormalization, Activation, Dense, Dropout,Maximum,Flatten
from keras.layers import Lambda, RepeatVector, Reshape

from keras.layers import Conv2D, Conv2DTranspose,Conv3D,Conv3DTranspose,UpSampling2D
# from tensorflow.keras.layers.convolutional import Conv2D, Conv2DTranspose,Conv3D,Conv3DTranspose,UpSampling2D
# from tensorflow.keras.layers.convolutional import Conv2D, Conv2DTranspose,Conv3D,Conv3DTranspose,UpSampling2D
from keras.layers import MaxPooling2D, GlobalMaxPool2D,MaxPooling3D,AveragePooling2D
from keras.layers import concatenate, add
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from sklearn.utils import class_weight
from keras.models import Sequential
import nibabel as nib

# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
path1 = '/kaggle/input/brats2018/MICCAI_BraTS_2018_Data_Training/survival_data.csv'
#print(os.listdir(path))
# Brats18_CBICA_ANP_1
# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import csv
#import pickle

#from joblib import dump

age_dict = {}
days_dict = {}




with open(path1, mode='r') as csv_file:
    csv_reader = csv.reader(csv_file,delimiter = ',')
    line_count = 0
    a = 0
    b = 0
    c = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            print(row)
            key = row[0]
            age = row[1]
            days = row[2]
            age_dict[key] = float(age)
            days_dict[key] = int(days)
            if int(days) < 250:
                a += 1
            elif (int(days) >= 250 and int(days) <= 500):
                b += 1
            else:
                c += 1
            line_count+=1

    print(f'Processed {line_count} lines.')
    #age_m = np.zeros((1,1))
    print(a,b,c)
# Out:
# Column names are BraTS18ID, Age, Survival, ResectionStatus
# ['Brats18_TCIA08_167_1', '74.907', '153', 'NA']
# ['Brats18_TCIA08_242_1', '66.479', '147', 'NA']
# ['Brats18_TCIA08_319_1', '64.86', '254', 'NA']
# ['Brats18_TCIA08_469_1', '63.899', '519', 'NA']
# ['Brats18_TCIA08_218_1', '57.345', '346', 'NA']
# ['Brats18_TCIA08_406_1', '78.745', '82', 'NA']
# ['Brats18_TCIA08_280_1', '57.362', '508', 'NA']
# ['Brats18_TCIA08_105_1', '66.627', '77', 'NA']
# ['Brats18_TCIA08_278_1', '50.501', '1458', 'NA']
# ['Brats18_TCIA06_247_1', '76.699', '244', 'NA']
# ['Brats18_TCIA06_372_1', '74.521', '213', 'NA']
# ['Brats18_TCIA06_165_1', '51.756', '5', 'NA']
# ['Brats18_TCIA06_409_1', '69.266', '99', 'NA']
# ['Brats18_TCIA06_184_1', '61.167', '434', 'NA']
# ['Brats18_TCIA05_277_1', '70.367', '232', 'NA']
# ['Brats18_TCIA05_478_1', '59.255', '30', 'NA']
# ['Brats18_TCIA04_437_1', '46.953', '333', 'NA']
# ['Brats18_TCIA04_361_1', '75.973', '476', 'NA']
# ['Brats18_TCIA04_192_1', '75.962', '121', 'NA']
# ['Brats18_TCIA04_479_1', '56.4', '372', 'NA']
# ['Brats18_TCIA04_111_1', '75.263', '626', 'NA']
# ['Brats18_TCIA04_343_1', '52.679', '296', 'NA']
# ['Brats18_TCIA04_149_1', '36.852', '448', 'NA']
# ['Brats18_TCIA03_474_1', '61.408', '635', 'NA']
# ['Brats18_TCIA03_419_1', '70.592', '327', 'NA']
# ['Brats18_TCIA03_199_1', '48.825', '1282', 'NA']
# ['Brats18_TCIA03_133_1', '63.762', '382', 'NA']
# ['Brats18_TCIA03_296_1', '60.427', '22', 'NA']
# ['Brats18_TCIA03_257_1', '69.326', '425', 'NA']
# ['Brats18_TCIA03_498_1', '59.282', '467', 'NA']
# ['Brats18_TCIA03_138_1', '71.874', '82', 'NA']
# ['Brats18_TCIA03_338_1', '76.425', '468', 'NA']
# ['Brats18_TCIA03_265_1', '59.584', '103', 'NA']
# ['Brats18_TCIA03_375_1', '60', '946', 'NA']
# ['Brats18_TCIA03_121_1', '30.408', '747', 'NA']
# ['Brats18_TCIA02_274_1', '54.967', '357', 'NA']
# ['Brats18_TCIA02_473_1', '61.022', '175', 'NA']
# ['Brats18_TCIA02_322_1', '57.362', '621', 'NA']
# ['Brats18_TCIA02_179_1', '46.677', '405', 'NA']
# ['Brats18_TCIA02_368_1', '62.562', '317', 'NA']
# ['Brats18_TCIA02_135_1', '69.364', '828', 'NA']
# ['Brats18_TCIA02_471_1', '76.614', '111', 'NA']
# ['Brats18_TCIA02_394_1', '64.247', '616', 'NA']
# ['Brats18_TCIA02_300_1', '64.378', '127', 'NA']
# ['Brats18_TCIA02_151_1', '47.973', '1731', 'NA']
# ['Brats18_TCIA02_118_1', '47.321', '104', 'NA']
# ['Brats18_TCIA02_226_1', '73.578', '329', 'NA']
# ['Brats18_TCIA02_455_1', '54.844', '424', 'NA']
# ['Brats18_TCIA02_283_1', '74.836', '262', 'NA']
# ['Brats18_TCIA02_430_1', '53.866', '71', 'NA']
# ['Brats18_TCIA02_321_1', '81.211', '67', 'NA']
# ['Brats18_TCIA02_314_1', '40.353', '362', 'NA']
# ['Brats18_TCIA02_290_1', '43.112', '737', 'NA']
# ['Brats18_TCIA02_377_1', '63.762', '812', 'NA']
# ['Brats18_TCIA02_198_1', '54.279', '394', 'NA']
# ['Brats18_TCIA02_331_1', '84.844', '187', 'NA']
# ['Brats18_TCIA02_491_1', '81.112', '82', 'NA']
# ['Brats18_TCIA01_150_1', '51.115', '1489', 'NA']
# ['Brats18_TCIA01_335_1', '54.474', '355', 'NA']
# ['Brats18_TCIA01_411_1', '42.904', '822', 'NA']
# ['Brats18_TCIA01_203_1', '45.926', '268', 'NA']
# ['Brats18_TCIA01_231_1', '63.805', '1561', 'NA']
# ['Brats18_TCIA01_390_1', '63.575', '634', 'NA']
# ['Brats18_TCIA01_235_1', '57.973', '804', 'NA']
# ['Brats18_TCIA01_499_1', '50.082', '600', 'NA']
# ['Brats18_TCIA01_412_1', '68.759', '291', 'NA']
# ['Brats18_TCIA01_448_1', '44.449', '199', 'NA']
# ['Brats18_TCIA01_401_1', '78.792', '448', 'NA']
# ['Brats18_TCIA01_147_1', '61.416', '209', 'NA']
# ['Brats18_TCIA01_378_1', '74.145', '110', 'NA']
# ['Brats18_TCIA01_201_1', '60.729', '430', 'NA']
# ['Brats18_TCIA01_429_1', '54.986', '86', 'NA']
# ['Brats18_TCIA01_186_1', '33.888', '370', 'NA']
# ['Brats18_TCIA01_460_1', '18.975', '630', 'NA']
# ['Brats18_TCIA01_190_1', '61.526', '322', 'NA']
# ['Brats18_TCIA01_425_1', '56.208', '558', 'NA']
# ['Brats18_2013_11_1', '29.12', '150', 'GTR']
# ['Brats18_2013_27_1', '68.02', '120', 'GTR']
# ['Brats18_CBICA_BHM_1', '62.03', '436', 'STR']
# ['Brats18_CBICA_BHB_1', '55.595', '510', 'GTR']
# ['Brats18_CBICA_AZH_1', '54.915', '401', 'GTR']
# ['Brats18_CBICA_AZD_1', '46.258', '448', 'GTR']
# ['Brats18_CBICA_AYW_1', '49.874', '734', 'NA']
# ['Brats18_CBICA_AYU_1', '63.781', '58', 'GTR']
# ['Brats18_CBICA_AYI_1', '65.921', '387', 'GTR']
# ['Brats18_CBICA_AYA_1', '74.836', '50', 'GTR']
# ['Brats18_CBICA_AXW_1', '79.211', '191', 'GTR']
# ['Brats18_CBICA_AXQ_1', '66.282', '114', 'GTR']
# ['Brats18_CBICA_AXO_1', '56.301', '394', 'NA']
# ['Brats18_CBICA_AXN_1', '85.762', '345', 'GTR']
# ['Brats18_CBICA_AXM_1', '66.934', '438', 'STR']
# ['Brats18_CBICA_AXL_1', '74.63', '168', 'GTR']
# ['Brats18_CBICA_AXJ_1', '27.811', '1767', 'GTR']
# ['Brats18_CBICA_AWI_1', '46.551', '375', 'GTR']
# ['Brats18_CBICA_AWH_1', '52.764', '139', 'GTR']
# ['Brats18_CBICA_AWG_1', '55.532', '180', 'GTR']
# ['Brats18_CBICA_AVV_1', '72.293', '387', 'GTR']
# ['Brats18_CBICA_AVJ_1', '45.244', '614', 'GTR']
# ['Brats18_CBICA_AVG_1', '63.359', '579', 'GTR']
# ['Brats18_CBICA_AUR_1', '70.252', '12', 'GTR']
# ['Brats18_CBICA_AUQ_1', '60.816', '1337', 'NA']
# ['Brats18_CBICA_AUN_1', '68.504', '376', 'GTR']
# ['Brats18_CBICA_ATX_1', '36.784', '1592', 'GTR']
# ['Brats18_CBICA_ATV_1', '62.159', '453', 'GTR']
# ['Brats18_CBICA_ATP_1', '51.589', '385', 'GTR']
# ['Brats18_CBICA_ATF_1', '68.726', '152', 'GTR']
# ['Brats18_CBICA_ATD_1', '69.178', '355', 'GTR']
# ['Brats18_CBICA_ATB_1', '71.126', '208', 'GTR']
# ['Brats18_CBICA_ASY_1', '66.51', '610', 'STR']
# ['Brats18_CBICA_ASW_1', '68.359', '239', 'GTR']
# ['Brats18_CBICA_ASV_1', '54.751', '597', 'GTR']
# ['Brats18_CBICA_ASU_1', '81.285', '85', 'STR']
# ['Brats18_CBICA_ASO_1', '52.348', '265', 'STR']
# ['Brats18_CBICA_ASN_1', '39.488', '407', 'STR']
# ['Brats18_CBICA_ASK_1', '77.337', '522', 'GTR']
# ['Brats18_CBICA_ASH_1', '46.57', '660', 'GTR']
# ['Brats18_CBICA_ASG_1', '57.71', '208', 'STR']
# ['Brats18_CBICA_ASE_1', '46.814', '318', 'STR']
# ['Brats18_CBICA_ASA_1', '63.764', '210', 'STR']
# ['Brats18_CBICA_ARZ_1', '54.825', '871', 'STR']
# ['Brats18_CBICA_ARW_1', '44.416', '495', 'STR']
# ['Brats18_CBICA_ARF_1', '75.312', '726', 'GTR']
# ['Brats18_CBICA_AQZ_1', '63.345', '286', 'STR']
# ['Brats18_CBICA_AQY_1', '57.718', '229', 'STR']
# ['Brats18_CBICA_AQV_1', '53.362', '84', 'GTR']
# ['Brats18_CBICA_AQU_1', '72.879', '30', 'STR']
# ['Brats18_CBICA_AQT_1', '75.978', '172', 'GTR']
# ['Brats18_CBICA_AQR_1', '71.37', '89', 'GTR']
# ['Brats18_CBICA_AQQ_1', '69.992', '33', 'STR']
# ['Brats18_CBICA_AQP_1', '46.452', '1283', 'GTR']
# ['Brats18_CBICA_AQO_1', '67.86', '473', 'GTR']
# ['Brats18_CBICA_AQN_1', '63.192', '488', 'STR']
# ['Brats18_CBICA_AQJ_1', '66.074', '170', 'STR']
# ['Brats18_CBICA_AQG_1', '53.605', '466', 'STR']
# ['Brats18_CBICA_AQD_1', '73.036', '32', 'STR']
# ['Brats18_CBICA_AQA_1', '76.367', '106', 'GTR']
# ['Brats18_CBICA_APZ_1', '60.063', '336', 'STR']
# ['Brats18_CBICA_APY_1', '45.548', '203', 'STR']
# ['Brats18_CBICA_APR_1', '62.704', '23', 'STR']
# ['Brats18_CBICA_AOZ_1', '46.666', '331', 'GTR']
# ['Brats18_CBICA_AOP_1', '67.833', '332', 'GTR']
# ['Brats18_CBICA_AOO_1', '44.162', '350', 'GTR']
# ['Brats18_CBICA_AOH_1', '56.921', '576', 'GTR']
# ['Brats18_CBICA_AOD_1', '60.581', '55', 'NA']
# ['Brats18_CBICA_ANZ_1', '68.049', '287', 'GTR']
# ['Brats18_CBICA_ANP_1', '61.605', '486', 'GTR']
# ['Brats18_CBICA_ANI_1', '58.258', '439', 'GTR']
# ['Brats18_CBICA_ANG_1', '55.759', '368', 'GTR']
# ['Brats18_CBICA_AMH_1', '62.614', '169', 'GTR']
# ['Brats18_CBICA_AME_1', '51.734', '359', 'GTR']
# ['Brats18_CBICA_ALX_1', '59.693', '698', 'GTR']
# ['Brats18_CBICA_ALU_1', '65.899', '495', 'GTR']
# ['Brats18_CBICA_ALN_1', '60.942', '421', 'STR']
# ['Brats18_CBICA_ABY_1', '48.367', '515', 'GTR']
# ['Brats18_CBICA_ABO_1', '56.419', '1155', 'GTR']
# ['Brats18_CBICA_ABN_1', '68.285', '1278', 'STR']
# ['Brats18_CBICA_ABM_1', '69.912', '503', 'GTR']
# ['Brats18_CBICA_ABE_1', '67.126', '269', 'GTR']
# ['Brats18_CBICA_ABB_1', '68.493', '465', 'GTR']
# ['Brats18_CBICA_AAP_1', '39.068', '788', 'GTR']
# ['Brats18_CBICA_AAL_1', '54.301', '464', 'GTR']
# ['Brats18_CBICA_AAG_1', '52.263', '616', 'GTR']
# ['Brats18_CBICA_AAB_1', '60.463', '289', 'GTR']
# Processed 164 lines.
# 55 64 44

# %%
def SurvPredNet(input_img,age_m):
    #input_img = BatchNormalization()(input_img)
    a1 = Conv2D(16,kernel_size = (3,3) , padding='same')(input_img)
    a1 = BatchNormalization()(a1)
    a1 = Activation('relu')(a1)
    
    a1 = MaxPooling2D(pool_size = (2,2) , strides = (2,2))(a1)
    
    a1 = Conv2D(24,kernel_size = (3,3) , padding='same')(a1)
    a1 = BatchNormalization()(a1)
    a1 = Activation('relu')(a1)
    
    a1 = MaxPooling2D(pool_size = (2,2) , strides = (2,2))(a1)
    
    a1 = Conv2D(32,kernel_size = (3,3) , padding='same')(a1)
    a1 = BatchNormalization()(a1)
    a1 = Activation('relu')(a1)
    
    a1 = MaxPooling2D(pool_size = (2,2) , strides = (2,2))(a1)
    
    a1 = Conv2D(32,kernel_size = (3,3) , padding='same')(a1)
    a1 = BatchNormalization()(a1)
    a1 = Activation('relu')(a1)
    
    a1 = MaxPooling2D(pool_size = (2,2) , strides = (2,2))(a1)
    
    a1 = Conv2D(32,kernel_size = (3,3) , padding='same')(a1)
    a1 = BatchNormalization()(a1)
    a1 = Activation('relu')(a1)
    
    a1 = AveragePooling2D(pool_size = (6,6) , strides = (1,1))(a1)
    
    a1 = Conv2D(32,kernel_size = (3,3) , padding = 'same')(a1)
    a1 = BatchNormalization()(a1)
    a1 = Activation('relu')(a1)
    
    a1 = AveragePooling2D(pool_size = (5,5) , strides = (1,1))(a1)
    a1 = Conv2D(32,kernel_size = (3,3) , padding = 'same')(a1)
    a1 = BatchNormalization()(a1)
    a1 = Activation('relu')(a1)
    
    a1 = AveragePooling2D(pool_size = (6,6) , strides = (1,1))(a1)
    
    a1 = Flatten()(a1)
    a1 = concatenate([a1,age_m])
    a1 = BatchNormalization()(a1)
    
    a1 = Dense(32,activation = 'relu')(a1)
    a1 = Dense(16,activation = 'relu')(a1)
    outputs = Dense(3,activation = 'softmax')(a1)
    
    model = Model(inputs = [input_img,age_m] , outputs = outputs)
    
    return model

# %%
input_img = Input((240,240,5))
age_m = Input((1))
model = SurvPredNet(input_img,age_m)
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 240, 240, 5)]        0         []
#
#  conv2d (Conv2D)             (None, 240, 240, 16)         736       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 240, 240, 16)         64        ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 240, 240, 16)         0         ['batch_normalization[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 120, 120, 16)         0         ['activation[0][0]']
#  D)
#
#  conv2d_1 (Conv2D)           (None, 120, 120, 24)         3480      ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (Bat  (None, 120, 120, 24)         96        ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 120, 120, 24)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 60, 60, 24)           0         ['activation_1[0][0]']
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 32)           6944      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 60, 60, 32)           128       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 60, 60, 32)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling2d_2 (MaxPoolin  (None, 30, 30, 32)           0         ['activation_2[0][0]']
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 30, 30, 32)           9248      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 30, 30, 32)           128       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 30, 30, 32)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling2d_3 (MaxPoolin  (None, 15, 15, 32)           0         ['activation_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 15, 15, 32)           9248      ['max_pooling2d_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 15, 15, 32)           128       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 15, 15, 32)           0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  average_pooling2d (Average  (None, 10, 10, 32)           0         ['activation_4[0][0]']
#  Pooling2D)
#
#  conv2d_5 (Conv2D)           (None, 10, 10, 32)           9248      ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (Bat  (None, 10, 10, 32)           128       ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 10, 10, 32)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  average_pooling2d_1 (Avera  (None, 6, 6, 32)             0         ['activation_5[0][0]']
#  gePooling2D)
#
#  conv2d_6 (Conv2D)           (None, 6, 6, 32)             9248      ['average_pooling2d_1[0][0]']
#
#  batch_normalization_6 (Bat  (None, 6, 6, 32)             128       ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 6, 6, 32)             0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  average_pooling2d_2 (Avera  (None, 1, 1, 32)             0         ['activation_6[0][0]']
#  gePooling2D)
#
#  flatten (Flatten)           (None, 32)                   0         ['average_pooling2d_2[0][0]']
#
#  input_2 (InputLayer)        [(None, 1)]                  0         []
#
#  concatenate (Concatenate)   (None, 33)                   0         ['flatten[0][0]',
#                                                                      'input_2[0][0]']
#
#  batch_normalization_7 (Bat  (None, 33)                   132       ['concatenate[0][0]']
#  chNormalization)
#
#  dense (Dense)               (None, 32)                   1088      ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  dense_1 (Dense)             (None, 16)                   528       ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 3)                    51        ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 50751 (198.25 KB)
# Trainable params: 50285 (196.43 KB)
# Non-trainable params: 466 (1.82 KB)
# __________________________________________________________________________________________________

# %%
path = '/kaggle/input/brats2018/MICCAI_BraTS_2018_Data_Training/HGG'
all_images = os.listdir(path)
#print(len(all_images))
all_images.sort()

def standardize(image):

  standardized_image = np.zeros(image.shape)

  #
 
      # iterate over the `z` dimension
  for z in range(image.shape[2]):
      # get a slice of the image
      # at channel c and z-th dimension `z`
      image_slice = image[:,:,z]

      # subtract the mean from image_slice
      centered = image_slice - np.mean(image_slice)
     
      # divide by the standard deviation (only if it is different from zero)
      if(np.std(centered)!=0):
          centered = centered/np.std(centered)

      # update  the slice of standardized image
      # with the scaled centered and scaled image
      standardized_image[:, :, z] = centered

  ### END CODE HERE ###

  return standardized_image

# %%
cnt = 0
for image_num in range(170):
    image1 = all_images[image_num]
    if image1 in days_dict:
        cnt += 1
        
print(cnt)
# Out:
# 134

# %%
loss_hist = []
accu_hist = []
epoch_wise_loss = []
epoch_wise_accu = []
#for epochs in range(45):
epoch_loss = 0
epoch_accu = 0
input_to_model = np.zeros((134,240,240,5))
age = np.zeros((134,1))
ground_truth = np.zeros((134,3))
cnt = 0
for image_num in range(170):
    #print(epochs)
    #print("image_num ",image_num)
    #print("cnt" ,cnt)
    data = np.zeros((240,240,155,4))
    image_data2=np.zeros((240,240,155))

    # data preprocessing starts here

    x = all_images[image_num]
    
    if x in days_dict:
        #print(cnt)
        #print(x)
        folder_path = path + '/' + x;
        modalities = os.listdir(folder_path)
        modalities.sort()
        #data = []
        w = 0
        for j in range(len(modalities)):
          #print(modalities[j])

          image_path = folder_path + '/' + modalities[j]
          if not(image_path.find('seg.nii') == -1):
            img = nib.load(image_path);
            image_data2 = img.get_fdata()
            image_data2 = np.asarray(image_data2)
            #print("Entered ground truth")
          else:
            img = nib.load(image_path);
            image_data = img.get_fdata()
            image_data = np.asarray(image_data)
            image_data = standardize(image_data)
            data[:,:,:,w] = image_data
            #print("Entered modality")
            w = w+1

        #print(data.shape)
        #print(image_data2.shape)
        image_data2[image_data2 == 4] = 3

        input_to_model[cnt,:,:,:4] = data[:,:,75,:]
        input_to_model[cnt,:,:,4] = image_data2[:,:,75]
        #age = np.zeros((1,1))
        age[cnt,0] = float(age_dict[x])
        days = int(days_dict[x])
        

        #ground_truth = np.zeros((1,3))
        #print(age[cnt,0])

        if int(days) < 300:
            ground_truth[cnt,0] = 1
        elif (int(days) >= 300 and int(days) <= 450):
            ground_truth[cnt,1] = 1
        else:
            ground_truth[cnt,2] = 1 
        
        #print(ground_truth[cnt])
        cnt += 1
        

    #y_to = keras.utils.to_categorical(y_to,num_classes=4)
history = model.fit(x=[input_to_model,age],y=ground_truth, epochs = 80 , batch_size = 64)
print(history.history['loss'])
#epoch_loss += history.history['loss'][0]
#epoch_accu += history.history['accuracy'][0]

#loss_hist.append(history.history['loss'])
#accu_hist.append(history.history['accuracy'])

model.save('../working/surv_pred3.h5')
#epoch_loss = epoch_loss/180
#epoch_accu = epoch_accu/180

#epoch_wise_loss.append(epoch_loss)
#epoch_wise_accu.append(epoch_accu)
 
plt.plot(history.history['loss'])
plt.title('Model_loss vs epochs')
plt.ylabel('Loss')
plt.xlabel('epochs')
s = '../working/epochwise_loss'
plt.savefig(s)
plt.show()
plt.close()

plt.plot(history.history['accuracy'])
plt.title('Model_Accuracy vs epochs')
plt.ylabel('Accuracy')
plt.xlabel('epochs')
s = '../working/epochwise_accuracy'
plt.savefig(s)
plt.show()
plt.close()
# Out:
# Epoch 1/80
# 3/3 [==============================] - 0s 42ms/step - loss: 0.2821 - accuracy: 0.9030
# Epoch 2/80
# 3/3 [==============================] - 0s 42ms/step - loss: 0.2034 - accuracy: 0.9403
# Epoch 3/80
# 3/3 [==============================] - 0s 43ms/step - loss: 0.2614 - accuracy: 0.9403
# Epoch 4/80
# 3/3 [==============================] - 0s 45ms/step - loss: 0.1656 - accuracy: 0.9776
# Epoch 5/80
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1382 - accuracy: 0.9925
# Epoch 6/80
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0899 - accuracy: 0.9925
# Epoch 7/80
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1267 - accuracy: 0.9701
# Epoch 8/80
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0747 - accuracy: 0.9851
# Epoch 9/80
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1232 - accuracy: 0.9627
# Epoch 10/80
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1638 - accuracy: 0.9328
# Epoch 11/80
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1124 - accuracy: 0.9701
# Epoch 12/80
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1507 - accuracy: 0.9552
# Epoch 13/80
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0847 - accuracy: 0.9552
# Epoch 14/80
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1079 - accuracy: 0.9627
# Epoch 15/80
# 3/3 [==============================] - 0s 46ms/step - loss: 0.1118 - accuracy: 0.9552
# Epoch 16/80
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0564 - accuracy: 1.0000
# Epoch 17/80
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0867 - accuracy: 0.9776
# Epoch 18/80
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1478 - accuracy: 0.9776
# Epoch 19/80
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2011 - accuracy: 0.9254
# Epoch 20/80
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0950 - accuracy: 0.9851
# Epoch 21/80
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0952 - accuracy: 0.9776
# Epoch 22/80
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1018 - accuracy: 0.9627
# Epoch 23/80
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1175 - accuracy: 0.9776
# Epoch 24/80
# 3/3 [==============================] - 0s 44ms/step - loss: 0.1045 - accuracy: 0.9552
# Epoch 25/80
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0709 - accuracy: 0.9776
# Epoch 26/80
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0709 - accuracy: 1.0000
# Epoch 27/80
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0744 - accuracy: 0.9925
# Epoch 28/80
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0821 - accuracy: 0.9776
# Epoch 29/80
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0485 - accuracy: 1.0000
# Epoch 30/80
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0544 - accuracy: 0.9925
# Epoch 31/80
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0630 - accuracy: 0.9925
# Epoch 32/80
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0658 - accuracy: 0.9776
# Epoch 33/80
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1162 - accuracy: 0.9701
# Epoch 34/80
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0457 - accuracy: 0.9851
# Epoch 35/80
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0689 - accuracy: 0.9851
# Epoch 36/80
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0959 - accuracy: 0.9552
# Epoch 37/80
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1153 - accuracy: 0.9478
# Epoch 38/80
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0482 - accuracy: 0.9925
# Epoch 39/80
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0509 - accuracy: 1.0000
# Epoch 40/80
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0856 - accuracy: 0.9701
# Epoch 41/80
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0497 - accuracy: 0.9851
# Epoch 42/80
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0384 - accuracy: 0.9851
# Epoch 43/80
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0631 - accuracy: 0.9776
# Epoch 44/80
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1066 - accuracy: 0.9627
# Epoch 45/80
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0690 - accuracy: 0.9851
# Epoch 46/80
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0831 - accuracy: 0.9776
# Epoch 47/80
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1181 - accuracy: 0.9552
# Epoch 48/80
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0590 - accuracy: 0.9851
# Epoch 49/80
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0539 - accuracy: 0.9851
# Epoch 50/80
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0599 - accuracy: 0.9776
# Epoch 51/80
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0439 - accuracy: 0.9925
# Epoch 52/80
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0349 - accuracy: 1.0000
# Epoch 53/80
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0515 - accuracy: 0.9851
# Epoch 54/80
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0405 - accuracy: 0.9925
# Epoch 55/80
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0400 - accuracy: 1.0000
# Epoch 56/80
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0591 - accuracy: 0.9851
# Epoch 57/80
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0808 - accuracy: 0.9701
# Epoch 58/80
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0649 - accuracy: 0.9776
# Epoch 59/80
# 3/3 [==============================] - 0s 43ms/step - loss: 0.1020 - accuracy: 0.9776
# Epoch 60/80
# 3/3 [==============================] - 0s 45ms/step - loss: 0.1187 - accuracy: 0.9627
# Epoch 61/80
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0563 - accuracy: 0.9851
# Epoch 62/80
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0665 - accuracy: 0.9776
# Epoch 63/80
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0809 - accuracy: 0.9627
# Epoch 64/80
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0474 - accuracy: 0.9925
# Epoch 65/80
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0592 - accuracy: 0.9776
# Epoch 66/80
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0378 - accuracy: 1.0000
# Epoch 67/80
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0688 - accuracy: 0.9776
# Epoch 68/80
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0426 - accuracy: 0.9925
# Epoch 69/80
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0356 - accuracy: 0.9851
# Epoch 70/80
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0411 - accuracy: 0.9851
# Epoch 71/80
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0475 - accuracy: 0.9851
# Epoch 72/80
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 73/80
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0435 - accuracy: 0.9851
# Epoch 74/80
# 3/3 [==============================] - 0s 44ms/step - loss: 0.1761 - accuracy: 0.9552
# Epoch 75/80
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1928 - accuracy: 0.9328
# Epoch 76/80
# 3/3 [==============================] - 0s 42ms/step - loss: 0.2027 - accuracy: 0.9328
# Epoch 77/80
# 3/3 [==============================] - 0s 42ms/step - loss: 0.1102 - accuracy: 0.9552
# Epoch 78/80
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1387 - accuracy: 0.9552
# Epoch 79/80
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1043 - accuracy: 0.9776
# Epoch 80/80
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1136 - accuracy: 0.9627
# [0.2820500135421753, 0.20338571071624756, 0.2614126205444336, 0.16560310125350952, 0.13815346360206604, 0.08985666185617447, 0.12670648097991943, 0.07467123121023178, 0.12322959303855896, 0.1637527346611023, 0.11243362724781036, 0.1506672203540802, 0.08469146490097046, 0.10790261626243591, 0.11177174001932144, 0.05635671317577362, 0.08670785278081894, 0.14778491854667664, 0.2011115849018097, 0.09495402127504349, 0.09520427137613297, 0.10183408111333847, 0.11748886108398438, 0.10448544472455978, 0.07094485312700272, 0.07085452973842621, 0.07438890635967255, 0.08213519304990768, 0.04851766675710678, 0.05443255603313446, 0.06296034157276154, 0.06576650589704514, 0.11618805676698685, 0.04572135582566261, 0.06891459226608276, 0.0958673432469368, 0.11532717198133469, 0.04824064299464226, 0.0508553721010685, 0.08560735732316971, 0.04970739036798477, 0.038350909948349, 0.0631083995103836, 0.10656512528657913, 0.06895141303539276, 0.08307988196611404, 0.11811542510986328, 0.05896066874265671, 0.053860265761613846, 0.0599096417427063, 0.043935663998126984, 0.03485687077045441, 0.051493898034095764, 0.04052823409438133, 0.04002828150987625, 0.05909413844347, 0.08081274479627609, 0.06489958614110947, 0.10200444608926773, 0.1186525821685791, 0.05631345137953758, 0.06646238267421722, 0.08085929602384567, 0.0474420003592968, 0.05922664701938629, 0.03775690868496895, 0.06876026839017868, 0.04257701337337494, 0.0356304831802845, 0.041101813316345215, 0.047451287508010864, 0.016975250095129013, 0.04351586848497391, 0.17611458897590637, 0.1927652806043625, 0.20265057682991028, 0.11024097353219986, 0.13874538242816925, 0.10432807356119156, 0.11360400915145874]

# %%
import numpy as np
import nibabel as nib
from keras.models import load_model

# Load the trained model
model = load_model('/kaggle/working/surv_pred3.h5')

# Path to your input image in NIfTI format
input_image_path = '/kaggle/input/brats2018/MICCAI_BraTS_2018_Data_Training/HGG/Brats18_2013_11_1/Brats18_2013_11_1_flair.nii'

# Load the NIfTI image
img = nib.load(input_image_path)
input_image_array = img.get_fdata()

# Assuming you also have age information for the input
# Replace this with your actual age data
input_age = np.array([[35]])

# Standardize the image
input_image_array = (input_image_array - np.mean(input_image_array)) / np.std(input_image_array)

# Extract a central slice along the depth dimension and stack along the last dimension
depth_slice = input_image_array[:, :, 75]  # Adjust the slice index as needed
input_image_array = np.stack([depth_slice] * 5, axis=-1)

# Make predictions
input_image_array = np.expand_dims(input_image_array, axis=0)  # Add batch dimension
predictions = model.predict([input_image_array, input_age])

# Get the predicted class
predicted_class = np.argmax(predictions)

# Define class labels and days range
class_labels = ["Less than 300 days", "Between 300 and 450 days", "More than 450 days"]
days_range = ["0-299", "300-449", "450+"]

# Print the predicted class and probabilities with days range
predicted_days_range = days_range[predicted_class]
print(f"Predicted Class: {class_labels[predicted_class]} ({predicted_days_range} days)")
print("Predicted Probabilities:", predictions.flatten())
# Out:
# 1/1 [==============================] - 0s 190ms/step
# Predicted Class: Between 300 and 450 days (300-449 days)
# Predicted Probabilities: [0.04528411 0.9409264  0.01378945]
